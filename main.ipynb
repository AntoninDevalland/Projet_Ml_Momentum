# %%
import pandas as pd 
import os

# %%
data = pd.read_excel(r"C:\Users\user\Bureau\Projet_Ml_Momentum\Momentum_project.xlsx", sheet_name="data_target_90", skiprows=1)
data2 = pd.read_excel(r"C:\Users\user\Bureau\Projet_Ml_Momentum\Momentum_project.xlsx", sheet_name="data_features_90", skiprows=1)
daa = pd.read_excel(r"C:\Users\user\Bureau\Projet_Ml_Momentum\Momentum_project.xlsx", sheet_name="daa", skiprows=1)

# %%
target = data.iloc[:, 1:11].copy()
features1 = data2.iloc[:, 1:30].copy()
features2 = daa.iloc[:, 1:30].copy()

target = target.set_index(target.columns[0])
features1 = features1.set_index(features1.columns[0])
features2 = features2.set_index(features2.columns[0])

target.index = pd.to_datetime(target.index, format = "%Y%m%d").copy()
print(target.head())
# Out:
#             Mkt-rf   SMB   HML   RMW   CMA    RF   Mom
# Date
# 1990-01-02    1.44 -0.68 -0.06  0.19 -0.44  0.03 -1.08
# 1990-01-03   -0.06  0.71 -0.26  0.16 -0.45  0.03 -0.31
# 1990-01-04   -0.71  0.44 -0.24 -0.05 -0.04  0.03 -0.34
# 1990-01-05   -0.85  0.73 -0.21  0.01 -0.12  0.03 -0.34
# 1990-01-08    0.30 -0.40 -0.27  0.04  0.30  0.03  0.19

# %%
features = features1.join(features2, how = 'inner').copy()


data = features.join(target, how = 'inner').copy()
print(data.head())
# Out:
#             DGS3MO  VIXCLS  DCOILWTICO  DAAA  DBAA  BAA10Y  NASDAQCOM  DGS10  \
# 1990-01-02    7.83   17.24       22.88  8.87  9.85    1.91     459.33   7.94
# 1990-01-03    7.89   18.19       23.81  8.90  9.86    1.87     460.90   7.99
# 1990-01-04    7.84   19.22       23.41  8.89  9.84    1.86     459.39   7.98
# 1990-01-05    7.79   20.11       23.07  8.88  9.88    1.89     458.22   7.99
# 1990-01-08    7.79   20.26       21.64  8.90  9.88    1.86     458.71   8.02
#
#             DGS1  DGS5  ...  DEXCAUS  DEXUSUK   DFF  Mkt-rf   SMB   HML   RMW  \
# 1990-01-02  7.81  7.87  ...   1.1605   1.6110  8.54    1.44 -0.68 -0.06  0.19
# 1990-01-03  7.85  7.92  ...   1.1613   1.6100  8.37   -0.06  0.71 -0.26  0.16
# 1990-01-04  7.82  7.91  ...   1.1614   1.6293  8.29   -0.71  0.44 -0.24 -0.05
# 1990-01-05  7.79  7.92  ...   1.1600   1.6370  8.20   -0.85  0.73 -0.21  0.01
# 1990-01-08  7.81  7.92  ...   1.1601   1.6530  8.27    0.30 -0.40 -0.27  0.04
#
#              CMA    RF   Mom
# ...

# %%
data.to_excel("data.xlsx", sheet_name= "X")
